# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # import dataframe

# %%
train = pd.read_csv(r"E:\project\house prive advance\train.csv")
test = pd.read_csv(r"E:\project\house prive advance\test.csv")

# %%
train.describe
# Out:
# <bound method NDFrame.describe of         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
train.shape
# Out:
# (1460, 81)

# %%
pd.options.display.max_columns
pd.options.display.max_rows
# Out:
# 60

# %% [markdown]
# # for finding null value sum

# %%
train.isnull().sum()
# Out:
# Id                 0
# MSSubClass         0
# MSZoning           0
# LotFrontage      259
# LotArea            0
#                 ...
# MoSold             0
# YrSold             0
# SaleType           0
# SaleCondition      0
# SalePrice          0
# Length: 81, dtype: int64

# %%
plt.figure(figsize=(25,25))
sns.heatmap(train.isnull(), yticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # data cleaning
#   in categorical columns using fillna methond imputing mode value
#   and in int value columns= data distrubution is bell shape then used mean methond if data skew then using median method

# %%
#fill missing values
train['LotFrontage']=train['LotFrontage'].fillna(train["LotFrontage"].mean())

# %%
train.drop(['Alley'], axis=1, inplace=True)

# %%
train.drop(['GarageYrBlt'],axis=1,inplace=True)

# %%
train['GarageFinish']=train['GarageFinish'].fillna(train['GarageFinish'].mode()[0])

# %% [markdown]
# # for dispaly max columns and rows

# %%
pd.set_option("display.max_columns", 80)
pd.set_option("display.max_rows", 1460)

# %%
train.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            0
# LotFrontage         0
# LotArea             0
# Street              0
# LotShape            0
# LandContour         0
# Utilities           0
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         0
# Exterior2nd         0
# MasVnrType          8
# MasVnrArea          8
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           37
# BsmtCond           37
# BsmtExposure       38
# BsmtFinType1       37
# BsmtFinSF1          0
# BsmtFinType2       38
# BsmtFinSF2          0
# BsmtUnfSF           0
# TotalBsmtSF         0
# Heating             0
# HeatingQC           0
# CentralAir          0
# ...

# %% [markdown]
# Drop unwanted columns

# %%
train.drop(['PoolQC','Fence', 'MiscFeature',], axis=1, inplace=True)

# %%
train['GarageType']=train['GarageType'].fillna(train['GarageType'].mode()[0])

# %%
train['BsmtQual']=train['BsmtQual'].fillna(train['BsmtQual'].mode()[0])
train['GarageCond']=train['GarageCond'].fillna(train['GarageCond'].mode()[0])

# %%
train['BsmtCond']=train['BsmtCond'].fillna(train['BsmtCond'].mode()[0])
train['BsmtExposure']=train['BsmtExposure'].fillna(train['BsmtExposure'].mode()[0])
train['BsmtFinType1']=train['BsmtFinType1'].fillna(train['BsmtFinType1'].mode()[0])
train['BsmtFinType2']=train['BsmtFinType2'].fillna(train['BsmtFinType2'].mode()[0])

# %%
train['BsmtCond']=train['BsmtCond'].fillna(train['BsmtCond'].mode()[0])
train['FireplaceQu']=train['FireplaceQu'].fillna(train['FireplaceQu'].mode()[0])

# %%
train['MasVnrType']=train['MasVnrType'].fillna(train['MasVnrType'].mode()[0])
train['MasVnrArea']=train['MasVnrArea'].fillna(train['MasVnrArea'].mode()[0])

# %%
train['GarageQual']=train['GarageQual'].fillna(train['GarageQual'].mode()[0])

# %%
train['Electrical']=train['Electrical'].fillna(train['Electrical'].mode()[0])

# %%
sns.heatmap(train.isnull(),yticklabels=False)
# Out:
# <AxesSubplot:>

# %% [markdown]
# For finding unique value in different columns using for loops

# %%
# find the unique values of each columns
for i in train.columns:
    print("Unique value of:>>>{} ({})\n{}\n".format(i, len(train[i].unique()), train[i].unique()))
# Out:
# Unique value of:>>>Id (1460)
# [   1    2    3 ... 1458 1459 1460]
#
# Unique value of:>>>MSSubClass (15)
# [ 60  20  70  50 190  45  90 120  30  85  80 160  75 180  40]
#
# Unique value of:>>>MSZoning (5)
# ['RL' 'RM' 'C (all)' 'FV' 'RH']
#
# Unique value of:>>>LotFrontage (111)
# [ 65.          80.          68.          60.          84.
#   85.          75.          70.04995837  51.          50.
#   70.          91.          72.          66.         101.
#   57.          44.         110.          98.          47.
#  108.         112.          74.         115.          61.
#   48.          33.          52.         100.          24.
#   89.          63.          76.          81.          95.
#   69.          21.          32.          78.         121.
#  122.          40.         105.          73.          77.
#   64.          94.          34.          90.          55.
#   88.          82.          71.         120.         107.
# ...

# %%
#plot the distplot of target
plt.figure(figsize=(10, 8))
bar = sns.distplot(train['SalePrice'])
# Out:
# C:\Users\sai\anaconda3\envs\py3-TF2.0\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
train['SalePrice'].skew()
# Out:
# 1.8828757597682129

# %%
 finding correkation between sales and other columns using heatmap
# Out:
#   File "<ipython-input-112-d49f037f3797>", line 1
#     finding correkation between sales and other columns using heatmap
#                       ^
# SyntaxError: invalid syntax

# %%
# correlation heatmap
plt.figure(figsize=(25,25))
ax= sns.heatmap(train.corr(), cmap="coolwarm", annot=True, linewidth=2)

# to fix the bug first and last row cut in half of heatmao plot
bottom, top =ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (37.5, -0.5)

# %% [markdown]
#  finding highly correlative

# %%
# correlation heatmap of highly correlated feature with saleprice
hig_corr = train.corr()
hig_corr_features = hig_corr.index[abs(hig_corr["SalePrice"]) >= 0.5]
hig_corr_features
# Out:
# Index(['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF',
#        'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea',
#        'SalePrice'],
#       dtype='object')

# %%
plt.figure(figsize=(10,8))
ax = sns.heatmap(train[hig_corr_features].corr(), cmap="coolwarm", annot=True, linewidth=3)
# to fix the bug "first and last row cut in half of heatmap plot"
bottom, top =ax.get_ylim()
ax.set_ylim(bottom + 0.5, top - 0.5)
# Out:
# (11.5, -0.5)

# %%
#plot regplot to gte the nature of highly correlated data
plt.figure(figsize=(16,9))
for i in range(len(hig_corr_features)):
    if i<= 9:
        plt.subplot(3, 4, i+1)
        plt.subplots_adjust(hspace = 0.5, wspace = 0.5)
        sns.regplot(data=train, x= hig_corr_features[i], y='SalePrice')

# %%
plt.figure(figsize=(16,9))
for i in range(len(hig_corr_features)):
    if i<= 9:
        plt.subplot(3, 4, i+1)
        plt.subplots_adjust(hspace = 0.5, wspace = 0.5)
        sns.boxplot(data=train, x= hig_corr_features[i], y='SalePrice')

# %%
train['MoSold'].unique()
# Out:
# array([ 2,  5,  9, 12, 10,  8, 11,  4,  1,  7,  3,  6], dtype=int64)

# %%
columns=['MSZoning','Street','LotShape','LandContour','Utilities','LotConfig','LandSlope','Neighborhood',
         'Condition2','BldgType','Condition1','HouseStyle','SaleType',
        'SaleCondition','ExterCond',
         'ExterQual','Foundation','BsmtQual','BsmtCond','BsmtExposure','BsmtFinType1','BsmtFinType2',
        'RoofStyle','RoofMatl','Exterior1st','Exterior2nd','MasVnrType','Heating','HeatingQC',
         'CentralAir',
         'Electrical','KitchenQual','Functional',
         'FireplaceQu','GarageType','GarageFinish','GarageQual','GarageCond','PavedDrive']

# %%
# combine test data 
test.head()
# Out:
#      Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0  1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1  1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2  1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3  1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4  1465         120       RL         43.0     5005   Pave   NaN      IR1
#
#   LandContour Utilities LotConfig LandSlope Neighborhood Condition1  \
# 0         Lvl    AllPub    Inside       Gtl        NAmes      Feedr
# 1         Lvl    AllPub    Corner       Gtl        NAmes       Norm
# 2         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 3         Lvl    AllPub    Inside       Gtl      Gilbert       Norm
# 4         HLS    AllPub    Inside       Gtl      StoneBr       Norm
#
#   Condition2 BldgType HouseStyle  OverallQual  OverallCond  YearBuilt  \
# ...

# %%
test.isnull().sum()
# Out:
# Id                  0
# MSSubClass          0
# MSZoning            4
# LotFrontage       227
# LotArea             0
# Street              0
# Alley            1352
# LotShape            0
# LandContour         0
# Utilities           2
# LotConfig           0
# LandSlope           0
# Neighborhood        0
# Condition1          0
# Condition2          0
# BldgType            0
# HouseStyle          0
# OverallQual         0
# OverallCond         0
# YearBuilt           0
# YearRemodAdd        0
# RoofStyle           0
# RoofMatl            0
# Exterior1st         1
# Exterior2nd         1
# MasVnrType         16
# MasVnrArea         15
# ExterQual           0
# ExterCond           0
# Foundation          0
# BsmtQual           44
# BsmtCond           45
# BsmtExposure       44
# BsmtFinType1       42
# BsmtFinSF1          1
# BsmtFinType2       42
# BsmtFinSF2          1
# BsmtUnfSF           1
# TotalBsmtSF         1
# Heating             0
# HeatingQC           0
# ...

# %%
test.drop(['Alley','PoolQC', 'Fence', 'MiscFeature','GarageYrBlt'], axis=1, inplace=True)

# %%
test.shape
# Out:
# (1459, 75)

# %%
sns.heatmap(test.isnull())
# Out:
# <AxesSubplot:>

# %%
#fill missing values
test['LotFrontage']=test['LotFrontage'].fillna(test["LotFrontage"].mean())

# %%
test['MSZoning']=test['MSZoning'].fillna(test["MSZoning"].mode())
test['FireplaceQu']=test['FireplaceQu'].fillna(test['FireplaceQu'].mode()[0])

# %%
test['Utilities']=test['Utilities'].fillna(test["Utilities"].mode())

# %%
test.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          4
# LotFrontage       0
# LotArea           0
# Street            0
# LotShape          0
# LandContour       0
# Utilities         2
# LotConfig         0
# LandSlope         0
# Neighborhood      0
# Condition1        0
# Condition2        0
# BldgType          0
# HouseStyle        0
# OverallQual       0
# OverallCond       0
# YearBuilt         0
# YearRemodAdd      0
# RoofStyle         0
# RoofMatl          0
# Exterior1st       1
# Exterior2nd       1
# MasVnrType       16
# MasVnrArea       15
# ExterQual         0
# ExterCond         0
# Foundation        0
# BsmtQual         44
# BsmtCond         45
# BsmtExposure     44
# BsmtFinType1     42
# BsmtFinSF1        1
# BsmtFinType2     42
# BsmtFinSF2        1
# BsmtUnfSF         1
# TotalBsmtSF       1
# Heating           0
# HeatingQC         0
# CentralAir        0
# Electrical        0
# 1stFlrSF          0
# 2ndFlrSF          0
# LowQualFinSF      0
# ...

# %%
test.shape
# Out:
# (1459, 75)

# %%
test['GarageType']=test['GarageType'].fillna(test['GarageType'].mode()[0])
test['GarageFinish']=test['GarageFinish'].fillna(test['GarageFinish'].mode()[0])
test['BsmtQual']=test['BsmtQual'].fillna(test['BsmtQual'].mode()[0])
test['GarageCond']=test['GarageCond'].fillna(test['GarageCond'].mode()[0])
test['BsmtCond']=test['BsmtCond'].fillna(test['BsmtCond'].mode()[0])
test['BsmtExposure']=test['BsmtExposure'].fillna(test['BsmtExposure'].mode()[0])
test['BsmtFinType1']=test['BsmtFinType1'].fillna(test['BsmtFinType1'].mode()[0])
test['BsmtFinType2']=test['BsmtFinType2'].fillna(test['BsmtFinType2'].mode()[0])
test['BsmtCond']=test['BsmtCond'].fillna(test['BsmtCond'].mode()[0])
test['MasVnrType']=test['MasVnrType'].fillna(test['MasVnrType'].mode()[0])
test['MasVnrArea']=test['MasVnrArea'].fillna(test['MasVnrArea'].mode()[0])
test['GarageQual']=test['GarageQual'].fillna(test['GarageQual'].mode()[0])
test['Electrical']=test['Electrical'].fillna(test['Electrical'].mode()[0])

# %%
test['BsmtFinSF1']=test['BsmtFinSF1'].fillna(test['BsmtFinSF1'].mode()[0])
test['Exterior2nd']=test['Exterior2nd'].fillna(test['Exterior2nd'].mode()[0])
test['Exterior1st']=test['Exterior1st'].fillna(test['Exterior1st'].mode()[0])
test['BsmtQual']=test['BsmtQual'].fillna(test['BsmtQual'].mode()[0])
test['BsmtFinSF2']=test['BsmtFinSF2'].fillna(test['BsmtFinSF2'].mode()[0])
test['BsmtUnfSF']=test['BsmtUnfSF'].fillna(test['BsmtUnfSF'].mode()[0])

# %%
test['TotalBsmtSF']=test['TotalBsmtSF'].fillna(test['TotalBsmtSF'].mode()[0])
test['BsmtFullBath']=test['BsmtFullBath'].fillna(test['BsmtFullBath'].mode()[0])
test['BsmtHalfBath']=test['BsmtHalfBath'].fillna(test['BsmtHalfBath'].mode()[0])
test['KitchenQual']=test['KitchenQual'].fillna(test['KitchenQual'].mode()[0])
test['Functional']=test['Functional'].fillna(test['Functional'].mode()[0])
test['GarageCars']=test['GarageCars'].fillna(test['GarageCars'].mode()[0])
test['GarageArea']=test['GarageArea'].fillna(test['GarageArea'].mode()[0])
test['SaleType']=test['SaleType'].fillna(test['SaleType'].mode()[0])

# %%
test.isnull().sum()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         4
# LotFrontage      0
# LotArea          0
# Street           0
# LotShape         0
# LandContour      0
# Utilities        2
# LotConfig        0
# LandSlope        0
# Neighborhood     0
# Condition1       0
# Condition2       0
# BldgType         0
# HouseStyle       0
# OverallQual      0
# OverallCond      0
# YearBuilt        0
# YearRemodAdd     0
# RoofStyle        0
# RoofMatl         0
# Exterior1st      0
# Exterior2nd      0
# MasVnrType       0
# MasVnrArea       0
# ExterQual        0
# ExterCond        0
# Foundation       0
# BsmtQual         0
# BsmtCond         0
# BsmtExposure     0
# BsmtFinType1     0
# BsmtFinSF1       0
# BsmtFinType2     0
# BsmtFinSF2       0
# BsmtUnfSF        0
# TotalBsmtSF      0
# Heating          0
# HeatingQC        0
# CentralAir       0
# Electrical       0
# 1stFlrSF         0
# 2ndFlrSF         0
# LowQualFinSF     0
# GrLivArea        0
# BsmtFullBath     0
# ...

# %%
final_df = pd.concat([train, test], axis=0)

# %%
final_df.shape
# Out:
# (2919, 76)

# %% [markdown]
# For one hot encoder using

# %%
def category_onehot_multcols(multcolumns):
    df_final=final_df
    i=0
    for fields in multcolumns:
        
        print(fields)
        df1=pd.get_dummies(final_df[fields],drop_first=True)
        
        final_df.drop([fields],axis=1,inplace=True)
        if i==0:
            df_final=df1.copy()
        else:
            
            df_final=pd.concat([df_final,df1],axis=1)
        i=i+1
       
        
    df_final=pd.concat([final_df,df_final],axis=1)
        
    return df_final

# %%
final_df= category_onehot_multcols(columns)
# Out:
# MSZoning
# Street
# LotShape
# LandContour
# Utilities
# LotConfig
# LandSlope
# Neighborhood
# Condition2
# BldgType
# Condition1
# HouseStyle
# SaleType
# SaleCondition
# ExterCond
# ExterQual
# Foundation
# BsmtQual
# BsmtCond
# BsmtExposure
# BsmtFinType1
# BsmtFinType2
# RoofStyle
# RoofMatl
# Exterior1st
# Exterior2nd
# MasVnrType
# Heating
# HeatingQC
# CentralAir
# Electrical
# KitchenQual
# Functional
# FireplaceQu
# GarageType
# GarageFinish
# GarageQual
# GarageCond
# PavedDrive

# %% [markdown]
# Drop dublicate columns

# %%
final_df = final_df.loc[:, ~final_df.columns.duplicated()]

# %%
final_df.shape
# Out:
# (2919, 177)

# %%
df_train=final_df.iloc[:1460,:]
df_test=final_df.iloc[1460:,:]

# %%
df_test.drop(['SalePrice'], axis=1, inplace=True)
# Out:
# C:\Users\sai\anaconda3\envs\py3-TF2.0\lib\site-packages\pandas\core\frame.py:4312: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
X_train=df_train.drop(['SalePrice'], axis=1)
y_train=df_train['SalePrice']

# %%
df_test.shape
# Out:
# (1459, 176)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
classifier_r=RandomForestClassifier(n_estimators=100, criterion='gini')

# %%
classifier_r.fit(X_train, y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred_r=classifier_r.predict(df_test)

# %% [markdown]
# for saving data csv file

# %%
submission = pd.DataFrame({
    'Id':df_test['Id'],
    'SalePrice':y_pred_r
})

submission.to_csv("home_price_prediction_rf1.csv", index=False)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
classifier_d = DecisionTreeClassifier(criterion ='gini')
classifier_d.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_d=classifier_r.predict(df_test)

# %%
submission = pd.DataFrame({
    'Id':df_test['Id'],
    'SalePrice':y_pred_r
})

submission.to_csv("home_price_prediction_dt1.csv", index=False)

# %%
final_df1 = pd.concat([train, test], axis=0)

# %%
final_df1.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
#        'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle',
#        'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'RoofStyle',
#        'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
#        'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
#        'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
#        'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', 'Heating', 'HeatingQC',
#        'CentralAir', 'Electrical', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF',
#        'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath',
#        'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual', 'TotRmsAbvGrd',
#        'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageFinish',
#        'GarageCars', 'GarageArea', 'GarageQual', 'GarageCond', 'PavedDrive',
# ...

# %%
overqual, Yearbuilt, Yearremotadd, TotalbsmtSf, 1stfirSF, GrlivArea, Fullbath, TotrmsAbvGrd,GarageCar, GarageArea, Saleprice
# Out:
#   File "<ipython-input-68-4619d74f5b13>", line 1
#     overqual, Yearbuilt, Yearremotadd, TotalbsmtSf, 1stfirSF, GrlivArea, Fullbath, TotrmsAbvGrd,GarageCar, GarageArea, Saleprice
#                                                            ^
# SyntaxError: invalid syntax

# %%
final_df1.drop(['MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
       'LotShape', 'LandContour', 'Utilities', 'LotConfig', 'LandSlope',
       'Neighborhood', 'Condition1', 'Condition2', 'BldgType', 'HouseStyle', 'OverallCond', 'RoofStyle',
       'RoofMatl', 'Exterior1st', 'Exterior2nd', 'MasVnrType', 'MasVnrArea',
       'ExterQual', 'ExterCond', 'Foundation', 'BsmtQual', 'BsmtCond',
       'BsmtExposure', 'BsmtFinType1', 'BsmtFinSF1', 'BsmtFinType2',
       'BsmtFinSF2', 'BsmtUnfSF', 'Heating', 'HeatingQC',
       'CentralAir', 'Electrical', '2ndFlrSF', 'LowQualFinSF', 'BsmtFullBath', 'BsmtHalfBath', 'HalfBath',
       'BedroomAbvGr', 'KitchenAbvGr', 'KitchenQual',
       'Functional', 'Fireplaces', 'FireplaceQu', 'GarageType', 'GarageFinish',
       'GarageQual', 'GarageCond', 'PavedDrive',
       'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
       'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SaleType',
       'SaleCondition'],axis=1,inplace=True)

# %%
final_df1.head()
# Out:
#    Id  OverallQual  YearBuilt  YearRemodAdd  TotalBsmtSF  1stFlrSF  GrLivArea  \
# 0   1            7       2003          2003        856.0       856       1710
# 1   2            6       1976          1976       1262.0      1262       1262
# 2   3            7       2001          2002        920.0       920       1786
# 3   4            7       1915          1970        756.0       961       1717
# 4   5            8       2000          2000       1145.0      1145       2198
#
#    FullBath  TotRmsAbvGrd  GarageCars  GarageArea  SalePrice
# 0         2             8         2.0       548.0   208500.0
# 1         2             6         2.0       460.0   181500.0
# 2         2             6         2.0       608.0   223500.0
# 3         1             7         3.0       642.0   140000.0
# 4         2             9         3.0       836.0   250000.0

# %%
df_train1=final_df1.iloc[:1460,:]
df_test1=final_df1.iloc[1460:,:]

# %%
df_test.shape
# Out:
# (1459, 176)

# %%
X_train1=df_train1.drop(['SalePrice'], axis=1)
y_train1=df_train1['SalePrice']

# %%
df_test1.drop(['SalePrice'], axis=1, inplace=True)
# Out:
# C:\Users\sai\anaconda3\envs\py3-TF2.0\lib\site-packages\pandas\core\frame.py:4312: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,

# %%
classifier_r.fit(X_train1, y_train1)
# Out:
# RandomForestClassifier()

# %%
y_pred_d1=classifier_r.predict(df_test1)

# %%
submission = pd.DataFrame({
    'Id':df_test['Id'],
    'SalePrice':y_pred_d1
})

submission.to_csv("home_price_prediction_dt12.csv", index=False)

# %%
import xgboost
xgb_reg = xgboost.XGBRegressor()
xgb_reg.fit(X_train1,y_train1)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=100, n_jobs=4, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
y_predx = xgb_reg.predict(df_test1)

# %%
submission = pd.DataFrame({
    'Id':df_test['Id'],
    'SalePrice':y_predx
})

submission.to_csv("home_price_prediction_xgb.csv", index=False)

# %%
classifier_d = DecisionTreeClassifier(criterion ='gini')
classifier_d.fit(X_train1, y_train1)
# Out:
# DecisionTreeClassifier()

# %%
y_pred_dc1=classifier_d.predict(df_test1)

# %%
submission = pd.DataFrame({
    'Id':df_test['Id'],
    'SalePrice':y_pred_dc1
})

submission.to_csv("home_price_prediction_dc12.csv", index=False)

# %%
from sklearn.linear_model import LogisticRegression

# %%
logmodel = LogisticRegression()
logmodel.fit(X_train1, y_train1)
# Out:
# C:\Users\sai\anaconda3\envs\py3-TF2.0\lib\site-packages\sklearn\linear_model\_logistic.py:765: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   extra_warning_msg=_LOGISTIC_SOLVER_CONVERGENCE_MSG)
# LogisticRegression()

# %%
predictions = logmodel.predict(df_test1)

# %%
submission = pd.DataFrame({
    'Id':df_test['Id'],
    'SalePrice':predictions
})

submission.to_csv("home_price_prediction_log.csv", index=False)

# %%
hig_corr = train.corr()
hig_corr_feature = hig_corr.index[abs(hig_corr['SalePrice']) >= 0.5]

# %%
hig_corr_feature
# Out:
# Index(['OverallQual', 'YearBuilt', 'YearRemodAdd', 'TotalBsmtSF', '1stFlrSF',
#        'GrLivArea', 'FullBath', 'TotRmsAbvGrd', 'GarageCars', 'GarageArea',
#        'SalePrice'],
#       dtype='object')

# %%
missing_col = train.columns[train.isnull().any()]
missing_col
# Out:
# Index([], dtype='object')

# %%
df = pd.concat([train, test], axis=0)

# %%
df.shape
# Out:
# (2919, 76)

# %%
import  calendar
df['MoSold'] = df['MoSold'].apply(lambda x: calendar.month_abbr[x])

# %%
df['MoSold'].unique()
# Out:
# array(['Feb', 'May', 'Sep', 'Dec', 'Oct', 'Aug', 'Nov', 'Apr', 'Jan',
#        'Jul', 'Mar', 'Jun'], dtype=object)
